# %%
import math

# %%
math.log10(1000)
# Out:
# 3.0

# %%
10**2.67
# Out:
# 467.73514128719813

# %%
10**2.65
# Out:
# 446.683592150963

# %%
10**2.662
# Out:
# 459.19801283686854

# %%
10**2.6619
# Out:
# 459.09229075913083

# %%
10**2.65
# Out:
# 446.683592150963

# %%
10**2.6610
# Out:
# 458.1418867145335

# %%
10**2.659
# Out:
# 456.03691595129595

# %%
10**2.6579
# Out:
# 454.8833073381455

# %%
10**2.6590
# Out:
# 456.03691595129595

# %%
10**2.65899
# Out:
# 456.02641543414325

# %%
10**2.658991
# Out:
# 456.02746547497804

# %%
10**2.6589900001
# Out:
# 456.02641553914725

# %%
10**2.65899900001
# Out:
# 456.0358658992013

# %%
10**2.65897700001
# Out:
# 456.0127651338054

# %%
10**2.65896500001
# Out:
# 456.0001652095376

# %%
(Log)10 of 456: 2.65896500001
