# %%
import matplotlib.pyplot as plt

# %%
bird = plt.imread('birdie.jpg')
plt.imshow(bird)

# %%
eye = bird[200:300, 800:900, :]
plt.imshow(eye)

# %%
eye_gray = eye.mean(axis=2)

plt.imshow(eye_gray)

# %%
plt.imshow(eye[:,:,::-1])

# %%
#magnify and scale down images: WIP
