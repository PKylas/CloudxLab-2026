# %%
import math

# %%
#93

def sq_guess(left, right):
    sqr = (left+right)/2
    print(sqr, sqr*sqr)

# %%
sq_guess(4,7)
# Out:
# 7.5 56.25

# %%
guess(5,8)
# Out:
# 9.0 81.0

# %%
sq_guess(6,8)
# Out:
# 7.0 49.0

# %%
sq_guess(8,10)
# Out:
# 9.0 81.0

# %%
sq_guess(8,11)
# Out:
# 9.5 90.25

# %%
sq_guess(8,12)
# Out:
# 10.0 100.0

# %%
sq_guess(8.5,11)
# Out:
# 9.75 95.0625

# %%
sq_guess(8.5,9)
# Out:
# 8.75 76.5625

# %%
sq_guess(8.5,10.5)
# Out:
# 9.5 90.25

# %%
sq_guess(9,11)
# Out:
# 10.0 100.0

# %%
sq_guess(8.5,10.95)
# Out:
# 9.725 94.57562499999999

# %%
sq_guess(8.3,10.75)
# Out:
# 9.525 90.72562500000001

# %%
sq_guess(8.5,10.85)
# Out:
# 9.675 93.60562500000002

# %%
sq_guess(8.5,10.849)
# Out:
# 9.6745 93.59595025

# %%
sq_guess(8.5,10.749)
# Out:
# 9.624500000000001 92.63100025000003

# %%
sq_guess(8.5,10.839)
# Out:
# 9.6695 93.49923024999998

# %%
sq_guess(8.5,10.819)
# Out:
# 9.659500000000001 93.30594025000002

# %%
sq_guess(8.5,10.8019)
# Out:
# 9.65095 93.1408359025

# %%
sq_guess(8.5,10.79019)
# Out:
# 9.645095000000001 93.02785755902502

# %%
sq_guess(8.5,10.76019)
# Out:
# 9.630095 92.73872970902501

# %%
sq_guess(8.5,10.789019)
# Out:
# 9.6445095 93.01656349559025

# %%
sq_guess(8.5,10.788019)
# Out:
# 9.6440095 93.00691923609024

# %%
sq_guess(8.5,10.786019)
# Out:
# 9.6430095 92.98763221709025

# %%
sq_guess(8.5,10.787019)
# Out:
# 9.6435095 92.99727547659026

# %%
sq_guess(8.5,10.7879019)
# Out:
# 9.64395095 93.00578992600592

# %%
sq_guess(8.5,10.7878019)
# Out:
# 9.643900949999999 93.00482553341088

# %%
sq_guess(8.5,10.7877019)
# Out:
# 9.643850950000001 93.00386114581592

# %%
sq_guess(8.5,10.7875019)
# Out:
# 9.643750950000001 93.00193238562592

# %%
sq_guess(8.5,10.7874019)
# Out:
# 9.64370095 93.0009680130309

# %%
Square root of 93 accurate to three decimal places: 9.64370095
